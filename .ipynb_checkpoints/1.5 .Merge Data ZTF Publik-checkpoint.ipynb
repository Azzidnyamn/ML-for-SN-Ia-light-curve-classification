# %%
import pandas as pd
import os

# Define the folder containing the CSV files
folder_path = 'TA_Azzidny/ZTF_Publik'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# List to hold dataframes
dataframes = []

# Read each CSV file and add to the list
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    len(df)
    dataframes.append(df)

# Concatenate all dataframes into a single dataframe
merged_df = pd.concat(dataframes, ignore_index=True)

# %%
# Save the merged dataframe to a new CSV file
output_path = os.path.join(folder_path, 'merged_output.csv')
merged_df.to_csv(output_path, index=False)

print(f'Merged CSV saved to {output_path}')

# %%
merged_df
# Out:
#        schemavsn                  publisher      objectId  \
# 0            3.3  ZTF (www.ztf.caltech.edu)  ZTF21aahprho
# 1            3.3  ZTF (www.ztf.caltech.edu)  ZTF23aacxjms
# 2            3.3  ZTF (www.ztf.caltech.edu)  ZTF18accnlhl
# 3            3.3  ZTF (www.ztf.caltech.edu)  ZTF18acwxdcl
# 4            3.3  ZTF (www.ztf.caltech.edu)  ZTF18aaijwki
# ...          ...                        ...           ...
# 24118        3.3  ZTF (www.ztf.caltech.edu)  ZTF20aaigeca
# 24119        3.3  ZTF (www.ztf.caltech.edu)  ZTF21acejhxn
# 24120        3.3  ZTF (www.ztf.caltech.edu)  ZTF23aagvfcw
# 24121        3.3  ZTF (www.ztf.caltech.edu)  ZTF18abqexic
# 24122        3.3  ZTF (www.ztf.caltech.edu)  ZTF22aadaotz
#
#                     candid                                          candidate  \
# 0      2266385270315015011  {'jd': 2460020.8852778, 'fid': 2, 'pid': 22663...
# 1      2266277750415015008  {'jd': 2460020.7777546, 'fid': 2, 'pid': 22662...
# ...

# %%
skema_33=merged_df.loc[merged_df['schemavsn'] == 3.3].reset_index(drop=True)

# %%
skema_33
# Out:
#        schemavsn                  publisher      objectId  \
# 0            3.3  ZTF (www.ztf.caltech.edu)  ZTF21aahprho
# 1            3.3  ZTF (www.ztf.caltech.edu)  ZTF23aacxjms
# 2            3.3  ZTF (www.ztf.caltech.edu)  ZTF18accnlhl
# 3            3.3  ZTF (www.ztf.caltech.edu)  ZTF18acwxdcl
# 4            3.3  ZTF (www.ztf.caltech.edu)  ZTF18aaijwki
# ...          ...                        ...           ...
# 19388        3.3  ZTF (www.ztf.caltech.edu)  ZTF20aaigeca
# 19389        3.3  ZTF (www.ztf.caltech.edu)  ZTF21acejhxn
# 19390        3.3  ZTF (www.ztf.caltech.edu)  ZTF23aagvfcw
# 19391        3.3  ZTF (www.ztf.caltech.edu)  ZTF18abqexic
# 19392        3.3  ZTF (www.ztf.caltech.edu)  ZTF22aadaotz
#
#                     candid                                          candidate  \
# 0      2266385270315015011  {'jd': 2460020.8852778, 'fid': 2, 'pid': 22663...
# 1      2266277750415015008  {'jd': 2460020.7777546, 'fid': 2, 'pid': 22662...
# ...

# %%
skema_44=merged_df.loc[merged_df['schemavsn'] > 3.3].reset_index(drop=True)
skema_44
# Out:
#       schemavsn                  publisher      objectId               candid  \
# 0          4.02  ZTF (www.ztf.caltech.edu)  ZTF23abudnet  2570279391015015008
# 1          4.02  ZTF (www.ztf.caltech.edu)  ZTF18adoxkzl  2570326210415015007
# 2          4.02  ZTF (www.ztf.caltech.edu)  ZTF19acdakhd  2570457443915015036
# 3          4.02  ZTF (www.ztf.caltech.edu)  ZTF21aafbcxo  2570254503515015005
# 4          4.02  ZTF (www.ztf.caltech.edu)  ZTF20aauryct  2570474244315015031
# ...         ...                        ...           ...                  ...
# 4725       4.02  ZTF (www.ztf.caltech.edu)  ZTF24aacbpej  2587126901215015010
# 4726       4.02  ZTF (www.ztf.caltech.edu)  ZTF18aabiyyj  2587175181515015025
# 4727       4.02  ZTF (www.ztf.caltech.edu)  ZTF23abpbdfm  2587387515215015004
# 4728       4.02  ZTF (www.ztf.caltech.edu)  ZTF23aamshoi  2587121675315015018
# 4729       4.02  ZTF (www.ztf.caltech.edu)  ZTF19ablgswl  2587132223715015006
#
# ...

# %%
unik_merg = merged_df['objectId'].nunique()
unik_merg
# Out:
# 10455

# %%
unik_33 = skema_33['objectId'].nunique()
unik_33
# Out:
# 8722

# %%
unik_44 = skema_44['objectId'].nunique()
unik_44
# Out:
# 2797

# %%
unik_33+unik_44
# Out:
# 11519

# %%
import matplotlib.pyplot as plt
jumlah_unik = [unik_merg, unik_33, unik_44]
kategori = ['Total', 'schema 3.3', 'schema 4.02']

# Membuat histogram
plt.figure(figsize=(8, 5))
colors = ['#C9A0DC', '#A0CBE8', '#F7A8A8'] 
plt.bar(kategori, jumlah_unik,color=colors)
plt.xlabel('schema version')
plt.ylabel('n')
plt.title('Jumlah objek berdasarkan schema version')
plt.show()

# %%
len(merged_df)
# Out:
# 24123

# %%
len(skema_33)
# Out:
# 19393

# %%
len(skema_44)
# Out:
# 4730

# %%
len(skema_33)+len(skema_44)
# Out:
# 24123

# %%
# Save the merged dataframe to a new CSV file
skema_44.to_csv('TA_Azzidny/skema_44.csv', index=False)
skema_33.to_csv('TA_Azzidny/skema_33.csv', index=False)
merged_df.to_csv('TA_Azzidny/merged_df.csv', index=False)
